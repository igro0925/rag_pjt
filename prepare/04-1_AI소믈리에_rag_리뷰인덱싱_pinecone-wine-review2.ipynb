# %% [markdown]
# # 와인 리뷰 데이터 인덱싱
# - 벡터 DB : PINECONE

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True, dotenv_path="../.env")

# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
# OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL")

# PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_INDEX_NAME = "wine-review2"
# PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")
PINECONE_NAMESPACE = "wine-review2-namespace"

# %% [markdown]
# # document loader

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader('./wine_reviews/winemag-data-130k-v2.csv')
docs = loader.load()
for i, d in enumerate(docs[:3]):
    print(i, d)
# Out:
# 0 page_content=': 0
# country: Italy
# description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
# designation: Vulkà Bianco
# points: 87
# price:
# province: Sicily & Sardinia
# region_1: Etna
# region_2:
# taster_name: Kerin O’Keefe
# taster_twitter_handle: @kerinokeefe
# title: Nicosia 2013 Vulkà Bianco  (Etna)
# variety: White Blend
# winery: Nicosia' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 0}
# 1 page_content=': 1
# country: Portugal
# description: This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.
# designation: Avidagos
# points: 87
# price: 15.0
# province: Douro
# region_1:
# region_2:
# taster_name: Roger Voss
# taster_twitter_handle: @vossroger
# title: Quinta dos Avidagos 2011 Avidagos Red (Douro)
# variety: Portuguese Red
# winery: Quinta dos Avidagos' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 1}
# 2 page_content=': 2
# country: US
# description: Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.
# designation:
# points: 87
# price: 14.0
# province: Oregon
# region_1: Willamette Valley
# region_2: Willamette Valley
# taster_name: Paul Gregutt
# taster_twitter_handle: @paulgwine
# title: Rainstorm 2013 Pinot Gris (Willamette Valley)
# variety: Pinot Gris
# winery: Rainstorm' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 2}

# %%
len(docs)
# Out:
# 129971

# %%
from langchain_pinecone import PineconeEmbeddings

embeddings = PineconeEmbeddings(
    model="llama-text-embed-v2"
)

# %% [markdown]
# # Pinecone객체, index객체 생성

# %%
from pinecone import Pinecone, ServerlessSpec


# Pinecone 클라이언트를 초기화(객체생성)
pc = Pinecone(api_key=PINECONE_API_KEY)

# %% [markdown]
# - index 있으면 삭제

# %%
# pc.list_indexes()
# PINECONE_INDEX_NAME

# for idx in pc.list_indexes():
#     print(idx.name)
#     if idx.name == PINECONE_INDEX_NAME:
#         pc.delete_index(idx.name)

# %% [markdown]
# - Pinecone 객체 생성, index 생성

# %% [markdown]
# - 업로딩에 기간이 좀 걸림, 경우에 따라 50분 정도 걸림
# - pinecone 월간 쓰기 작업 제한(Write Unit Limit)을 초과하면 더이상 업로딩을 못함

# %% [markdown]
# # Split 객체 생성

# %%
# split하기
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 분할기 설정 (예: 1000자씩 분할)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=100,
    # length_function=tiktoken_len,  # 토큰 기반 길이 측정    
    length_function=len,  # 문자수   
    separators=["\n\n", "\n", " ", ""]
    )

# 문서를 분할
chunks = text_splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 129982

# %%
print(chunks[2])
# Out:
# page_content=': 2
# country: US
# description: Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.
# designation:
# points: 87
# price: 14.0
# province: Oregon
# region_1: Willamette Valley
# region_2: Willamette Valley
# taster_name: Paul Gregutt
# taster_twitter_handle: @paulgwine
# title: Rainstorm 2013 Pinot Gris (Willamette Valley)
# variety: Pinot Gris
# winery: Rainstorm' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 2}

# %% [markdown]
# # 배치 크기 단위로 저장하기

# %% [markdown]
# - langchain_pinecone의 PineconeVectorStore으로 벡터 DB에 저장

# %%
from langchain_pinecone import PineconeVectorStore

BATCH_SIZE = 500

for i in range(0, len(chunks), BATCH_SIZE):
    batch_docs = chunks[i:i + BATCH_SIZE]

    if i == 0:
        vector_store = PineconeVectorStore.from_documents(
            documents=batch_docs,
            embedding=embeddings,
            index_name=PINECONE_INDEX_NAME,
            namespace=PINECONE_NAMESPACE,
        )
    else:
        vector_store.add_documents(batch_docs)

    print(f"배치 {i//BATCH_SIZE + 1} 완료: {len(batch_docs)}개 업로드")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[16], line 11
#       9 # 첫 번째 배치로 벡터 스토어 생성
#      10 if i == 0:
# ---> 11     vector_store = PineconeVectorStore.from_documents(
#      12         batch_docs,            # BATCH_SIZE 수 만큼의 chunk
#      13         embedding=embeddings,  # 임베딩 벡터로 변환
#      14         index_name=PINECONE_INDEX_NAME,   # index 이름
#      15         namespace=PINECONE_NAMESPACE
#      16     )
#      18 # 이후 배치는 생성한 벡터 스토어에 추가, # 내부적으로 임베딩 벡터로 변환
#      19 else:
#      20     vector_store.add_documents(batch_docs)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_core\vectorstores\base.py:813, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     810     if any(ids):
#     811         kwargs["ids"] = ids
# --> 813 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_pinecone\vectorstores.py:978, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     975 pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     976 pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
# --> 978 pinecone.add_texts(
#     979     texts,
#     980     metadatas=metadatas,
#     981     ids=ids,
#     982     namespace=namespace,
#     983     batch_size=batch_size,
#     984     embedding_chunk_size=embeddings_chunk_size,
#     985     async_req=async_req,
#     986     id_prefix=id_prefix,
#     987     **(upsert_kwargs or {}),
#     988 )
#     989 return pinecone
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_pinecone\vectorstores.py:357, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     355 chunk_ids = ids[i : i + embedding_chunk_size]
#     356 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 357 embeddings = self._embedding.embed_documents(chunk_texts)
#     358 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     359 if async_req:
#     360     # Runs the pinecone upsert asynchronously.
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_openai\embeddings\base.py:709, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     706 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     707 # This could be optimized to avoid double work when all texts are short enough.
#     708 engine = cast(str, self.deployment)
# --> 709 return self._get_len_safe_embeddings(
#     710     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     711 )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_openai\embeddings\base.py:576, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     574 # Make API call with this batch
#     575 batch_tokens = tokens[i:batch_end]
# --> 576 response = self.client.create(input=batch_tokens, **client_kwargs)
#     577 if not isinstance(response, dict):
#     578     response = response.model_dump()
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `llama-text-embed-v2` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %%
# =========================
# 0. 환경 변수 로드
# =========================
from dotenv import load_dotenv
import os
import time

load_dotenv(override=True, dotenv_path="../.env")

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

PINECONE_INDEX_NAME = "wine-review2"
PINECONE_NAMESPACE = "wine-review2-namespace"


# =========================
# 1. Pinecone 초기화
# =========================
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key=PINECONE_API_KEY)

existing_indexes = [idx["name"] for idx in pc.list_indexes().indexes]

# =========================
# 2. 기존 인덱스 삭제 (있다면)
# =========================
if PINECONE_INDEX_NAME in existing_indexes:
    print(f"기존 인덱스 삭제 중: {PINECONE_INDEX_NAME}")
    pc.delete_index(PINECONE_INDEX_NAME)

    # 삭제 반영 대기
    time.sleep(10)

# =========================
# 3. 인덱스 재생성 (⭐ dimension=1024)
# =========================
print("새 인덱스 생성 중...")

pc.create_index(
    name=PINECONE_INDEX_NAME,
    dimension=1024,            # llama-text-embed-v2와 차원 맞춰주기
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)

print("인덱스 생성 완료")

# 인덱스 준비 대기
while not pc.describe_index(PINECONE_INDEX_NAME).status["ready"]:
    print("인덱스 준비 중...")
    time.sleep(5)

print("인덱스 ready 상태")


# =========================
# 4. 문서 로드 (CSV)
# =========================
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader("./wine_reviews/winemag-data-130k-v2.csv")
docs = loader.load()

print(f"원본 문서 수: {len(docs)}")


# =========================
# 5. 문서 분할
# =========================
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len,
    separators=["\n\n", "\n", " ", ""]
)

chunks = text_splitter.split_documents(docs)
print(f"분할된 chunk 수: {len(chunks)}")


# =========================
# 6. Pinecone Embeddings
# =========================
from langchain_pinecone import PineconeEmbeddings

embeddings = PineconeEmbeddings(
    model="llama-text-embed-v2"
)


# =========================
# 7. Pinecone Vector Store 업로드
# =========================
from langchain_pinecone import PineconeVectorStore
import time

BATCH_SIZE = 100
SLEEP_TIME = 10  

for i in range(0, len(chunks), BATCH_SIZE):
    batch_docs = chunks[i:i + BATCH_SIZE]

    if i == 0:
        vector_store = PineconeVectorStore.from_documents(
            documents=batch_docs,
            embedding=embeddings,
            index_name=PINECONE_INDEX_NAME,
            namespace=PINECONE_NAMESPACE,
        )
    else:
        vector_store.add_documents(batch_docs)

    print(f"배치 {i // BATCH_SIZE + 1} 완료: {len(batch_docs)}개 업로드")

    time.sleep(SLEEP_TIME)

print("전체 업로드 완료")
# Out:
# 새 인덱스 생성 중...
# 인덱스 생성 완료
# 인덱스 ready 상태
# 원본 문서 수: 129971
# 분할된 chunk 수: 129982
# 배치 1 완료: 100개 업로드
# 배치 2 완료: 100개 업로드
# 배치 3 완료: 100개 업로드
# 배치 4 완료: 100개 업로드
# 배치 5 완료: 100개 업로드
# 배치 6 완료: 100개 업로드
# 배치 7 완료: 100개 업로드
# 배치 8 완료: 100개 업로드
# 배치 9 완료: 100개 업로드
# 배치 10 완료: 100개 업로드
# 배치 11 완료: 100개 업로드
# 배치 12 완료: 100개 업로드
# 배치 13 완료: 100개 업로드
# 배치 14 완료: 100개 업로드
# 배치 15 완료: 100개 업로드
# 배치 16 완료: 100개 업로드
# 배치 17 완료: 100개 업로드
# 배치 18 완료: 100개 업로드
# 배치 19 완료: 100개 업로드
# 배치 20 완료: 100개 업로드
# 배치 21 완료: 100개 업로드
# 배치 22 완료: 100개 업로드
# 배치 23 완료: 100개 업로드
# 배치 24 완료: 100개 업로드
# 배치 25 완료: 100개 업로드
# 배치 26 완료: 100개 업로드
# 배치 27 완료: 100개 업로드
# 배치 28 완료: 100개 업로드
# 배치 29 완료: 100개 업로드
# 배치 30 완료: 100개 업로드
# 배치 31 완료: 100개 업로드
# 배치 32 완료: 100개 업로드
# 배치 33 완료: 100개 업로드
# 배치 34 완료: 100개 업로드
# 배치 35 완료: 100개 업로드
# 배치 36 완료: 100개 업로드
# 배치 37 완료: 100개 업로드
# 배치 38 완료: 100개 업로드
# 배치 39 완료: 100개 업로드
# 배치 40 완료: 100개 업로드
# 배치 41 완료: 100개 업로드
# 배치 42 완료: 100개 업로드
# 배치 43 완료: 100개 업로드
# 배치 44 완료: 100개 업로드
# 배치 45 완료: 100개 업로드
# 배치 46 완료: 100개 업로드
# 배치 47 완료: 100개 업로드
# 배치 48 완료: 100개 업로드
# 배치 49 완료: 100개 업로드
# 배치 50 완료: 100개 업로드
# 배치 51 완료: 100개 업로드
# 배치 52 완료: 100개 업로드
# 배치 53 완료: 100개 업로드
# 배치 54 완료: 100개 업로드
# 배치 55 완료: 100개 업로드
# 배치 56 완료: 100개 업로드
# 배치 57 완료: 100개 업로드
# 배치 58 완료: 100개 업로드
# 배치 59 완료: 100개 업로드
# 배치 60 완료: 100개 업로드
# 배치 61 완료: 100개 업로드
# 배치 62 완료: 100개 업로드
# 배치 63 완료: 100개 업로드
# 배치 64 완료: 100개 업로드
# 배치 65 완료: 100개 업로드
# 배치 66 완료: 100개 업로드
# 배치 67 완료: 100개 업로드
# 배치 68 완료: 100개 업로드
# 배치 69 완료: 100개 업로드
# 배치 70 완료: 100개 업로드
# 배치 71 완료: 100개 업로드
# 배치 72 완료: 100개 업로드
# 배치 73 완료: 100개 업로드
# 배치 74 완료: 100개 업로드
# 배치 75 완료: 100개 업로드
# 배치 76 완료: 100개 업로드
# 배치 77 완료: 100개 업로드
# 배치 78 완료: 100개 업로드
# 배치 79 완료: 100개 업로드
# 배치 80 완료: 100개 업로드
# 배치 81 완료: 100개 업로드
# 배치 82 완료: 100개 업로드
# 배치 83 완료: 100개 업로드
# 배치 84 완료: 100개 업로드
# 배치 85 완료: 100개 업로드
# 배치 86 완료: 100개 업로드
# 배치 87 완료: 100개 업로드
# 배치 88 완료: 100개 업로드
# 배치 89 완료: 100개 업로드
# 배치 90 완료: 100개 업로드
# 배치 91 완료: 100개 업로드
# 배치 92 완료: 100개 업로드
# 배치 93 완료: 100개 업로드
# 배치 94 완료: 100개 업로드
# 배치 95 완료: 100개 업로드
# 배치 96 완료: 100개 업로드
# 배치 97 완료: 100개 업로드
# 배치 98 완료: 100개 업로드
# 배치 99 완료: 100개 업로드
# 배치 100 완료: 100개 업로드
# 배치 101 완료: 100개 업로드
# 배치 102 완료: 100개 업로드
# 배치 103 완료: 100개 업로드
# 배치 104 완료: 100개 업로드
# 배치 105 완료: 100개 업로드
# 배치 106 완료: 100개 업로드
# 배치 107 완료: 100개 업로드
# 배치 108 완료: 100개 업로드
# 배치 109 완료: 100개 업로드
# 배치 110 완료: 100개 업로드
# 배치 111 완료: 100개 업로드
# 배치 112 완료: 100개 업로드
# 배치 113 완료: 100개 업로드
# 배치 114 완료: 100개 업로드
# 배치 115 완료: 100개 업로드
# 배치 116 완료: 100개 업로드
# 배치 117 완료: 100개 업로드
# 배치 118 완료: 100개 업로드
# 배치 119 완료: 100개 업로드
# 배치 120 완료: 100개 업로드
# 배치 121 완료: 100개 업로드
# 배치 122 완료: 100개 업로드
# 배치 123 완료: 100개 업로드
# 배치 124 완료: 100개 업로드
# 배치 125 완료: 100개 업로드
# 배치 126 완료: 100개 업로드
# 배치 127 완료: 100개 업로드
# 배치 128 완료: 100개 업로드
# 배치 129 완료: 100개 업로드
# 배치 130 완료: 100개 업로드
# 배치 131 완료: 100개 업로드
# 배치 132 완료: 100개 업로드
# 배치 133 완료: 100개 업로드
# 배치 134 완료: 100개 업로드
# 배치 135 완료: 100개 업로드
# 배치 136 완료: 100개 업로드
# 배치 137 완료: 100개 업로드
# 배치 138 완료: 100개 업로드
# 배치 139 완료: 100개 업로드
# 배치 140 완료: 100개 업로드
# 배치 141 완료: 100개 업로드
# 배치 142 완료: 100개 업로드
# 배치 143 완료: 100개 업로드
# 배치 144 완료: 100개 업로드
# 배치 145 완료: 100개 업로드
# 배치 146 완료: 100개 업로드
# 배치 147 완료: 100개 업로드
# 배치 148 완료: 100개 업로드
# 배치 149 완료: 100개 업로드
# 배치 150 완료: 100개 업로드
# 배치 151 완료: 100개 업로드
# 배치 152 완료: 100개 업로드
# 배치 153 완료: 100개 업로드
# 배치 154 완료: 100개 업로드
# 배치 155 완료: 100개 업로드
# 배치 156 완료: 100개 업로드
# 배치 157 완료: 100개 업로드
# 배치 158 완료: 100개 업로드
# 배치 159 완료: 100개 업로드
# 배치 160 완료: 100개 업로드
# 배치 161 완료: 100개 업로드
# 배치 162 완료: 100개 업로드
# 배치 163 완료: 100개 업로드
# 배치 164 완료: 100개 업로드
# 배치 165 완료: 100개 업로드
# 배치 166 완료: 100개 업로드
# 배치 167 완료: 100개 업로드
# 배치 168 완료: 100개 업로드
# 배치 169 완료: 100개 업로드
# 배치 170 완료: 100개 업로드
# 배치 171 완료: 100개 업로드
# 배치 172 완료: 100개 업로드
# 배치 173 완료: 100개 업로드
# 배치 174 완료: 100개 업로드
# 배치 175 완료: 100개 업로드
# 배치 176 완료: 100개 업로드
# 배치 177 완료: 100개 업로드
# 배치 178 완료: 100개 업로드
# 배치 179 완료: 100개 업로드
# 배치 180 완료: 100개 업로드
# 배치 181 완료: 100개 업로드
# 배치 182 완료: 100개 업로드
# 배치 183 완료: 100개 업로드
# 배치 184 완료: 100개 업로드
# 배치 185 완료: 100개 업로드
# 배치 186 완료: 100개 업로드
# 배치 187 완료: 100개 업로드
# 배치 188 완료: 100개 업로드
# 배치 189 완료: 100개 업로드
# 배치 190 완료: 100개 업로드
# 배치 191 완료: 100개 업로드
# 배치 192 완료: 100개 업로드
# 배치 193 완료: 100개 업로드
# 배치 194 완료: 100개 업로드
# 배치 195 완료: 100개 업로드
# 배치 196 완료: 100개 업로드
# 배치 197 완료: 100개 업로드
# 배치 198 완료: 100개 업로드
# 배치 199 완료: 100개 업로드
# 배치 200 완료: 100개 업로드
# 배치 201 완료: 100개 업로드
# 배치 202 완료: 100개 업로드
# 배치 203 완료: 100개 업로드
# 배치 204 완료: 100개 업로드
# 배치 205 완료: 100개 업로드
# 배치 206 완료: 100개 업로드
# 배치 207 완료: 100개 업로드
# 배치 208 완료: 100개 업로드
# 배치 209 완료: 100개 업로드
# 배치 210 완료: 100개 업로드
# 배치 211 완료: 100개 업로드
# 배치 212 완료: 100개 업로드
# 배치 213 완료: 100개 업로드
# 배치 214 완료: 100개 업로드
# 배치 215 완료: 100개 업로드
# 배치 216 완료: 100개 업로드
# 배치 217 완료: 100개 업로드
# 배치 218 완료: 100개 업로드
# 배치 219 완료: 100개 업로드
# 배치 220 완료: 100개 업로드
# 배치 221 완료: 100개 업로드
# 배치 222 완료: 100개 업로드
# 배치 223 완료: 100개 업로드
# 배치 224 완료: 100개 업로드
# 배치 225 완료: 100개 업로드
# 배치 226 완료: 100개 업로드
# 배치 227 완료: 100개 업로드
# 배치 228 완료: 100개 업로드
# 배치 229 완료: 100개 업로드
# 배치 230 완료: 100개 업로드
# 배치 231 완료: 100개 업로드
# 배치 232 완료: 100개 업로드
# 배치 233 완료: 100개 업로드
# 배치 234 완료: 100개 업로드
# 배치 235 완료: 100개 업로드
# 배치 236 완료: 100개 업로드
# 배치 237 완료: 100개 업로드
# 배치 238 완료: 100개 업로드
# 배치 239 완료: 100개 업로드
# 배치 240 완료: 100개 업로드
# 배치 241 완료: 100개 업로드
# 배치 242 완료: 100개 업로드
# 배치 243 완료: 100개 업로드
# 배치 244 완료: 100개 업로드
# 배치 245 완료: 100개 업로드
# 배치 246 완료: 100개 업로드
# 배치 247 완료: 100개 업로드
# 배치 248 완료: 100개 업로드
# 배치 249 완료: 100개 업로드
# 배치 250 완료: 100개 업로드
# 배치 251 완료: 100개 업로드
# 배치 252 완료: 100개 업로드
# 배치 253 완료: 100개 업로드
# 배치 254 완료: 100개 업로드
# 배치 255 완료: 100개 업로드
# 배치 256 완료: 100개 업로드
# 배치 257 완료: 100개 업로드
# 배치 258 완료: 100개 업로드
# 배치 259 완료: 100개 업로드
# 배치 260 완료: 100개 업로드
# 배치 261 완료: 100개 업로드
# 배치 262 완료: 100개 업로드
# 배치 263 완료: 100개 업로드
# 배치 264 완료: 100개 업로드
# 배치 265 완료: 100개 업로드
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[7], line 117
#     110     vector_store = PineconeVectorStore.from_documents(
#     111         documents=batch_docs,
#     112         embedding=embeddings,
#     113         index_name=PINECONE_INDEX_NAME,
#     114         namespace=PINECONE_NAMESPACE,
#     115     )
#     116 else:
# --> 117     vector_store.add_documents(batch_docs)
#     119 print(f"배치 {i // BATCH_SIZE + 1} 완료: {len(batch_docs)}개 업로드")
#     121 time.sleep(SLEEP_TIME)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_core\vectorstores\base.py:257, in VectorStore.add_documents(self, documents, **kwargs)
#     255     texts = [doc.page_content for doc in documents]
#     256     metadatas = [doc.metadata for doc in documents]
# --> 257     return self.add_texts(texts, metadatas, **kwargs)
#     258 msg = (
#     259     f"`add_documents` and `add_texts` has not been implemented "
#     260     f"for {self.__class__.__name__} "
#     261 )
#     262 raise NotImplementedError(msg)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_pinecone\vectorstores.py:357, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     355 chunk_ids = ids[i : i + embedding_chunk_size]
#     356 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 357 embeddings = self._embedding.embed_documents(chunk_texts)
#     358 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     359 if async_req:
#     360     # Runs the pinecone upsert asynchronously.
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_pinecone\embeddings.py:213, in PineconeEmbeddings.embed_documents(self, texts)
#     211 _iter, batch_size = self._get_batch_iterator(texts)
#     212 for i in _iter:
# --> 213     response = self._embed_texts(
#     214         model=self.model,
#     215         parameters=self.document_params,
#     216         texts=texts[i : i + batch_size],
#     217     )
#     218     embeddings.extend([r["values"] for r in response])
#     220 return embeddings
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\langchain_pinecone\embeddings.py:252, in PineconeEmbeddings._embed_texts(self, texts, model, parameters)
#     249 def _embed_texts(
#     250     self, texts: List[str], model: str, parameters: dict
#     251 ) -> EmbeddingsList:
# --> 252     return self._client.inference.embed(
#     253         model=model, inputs=texts, parameters=parameters
#     254     )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\inference\inference.py:191, in Inference.embed(self, model, inputs, parameters)
#     156 """
#     157 Generates embeddings for the provided inputs using the specified model and (optional) parameters.
#     158
#    (...)    186
#     187 """
#     188 request_body = InferenceRequestBuilder.embed_request(
#     189     model=model, inputs=inputs, parameters=parameters
#     190 )
# --> 191 resp = self.__inference_api.embed(embed_request=request_body)
#     192 return EmbeddingsList(resp)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\core\openapi\inference\api\inference_api.py:82, in InferenceApi.__init__.<locals>.__embed(self, **kwargs)
#      47 """Generate vectors  # noqa: E501
#      48
#      49 Generate vector embeddings for input data. This endpoint uses Pinecone's [hosted embedding models](https://docs.pinecone.io/guides/index-data/create-an-index#embedding-models).  # noqa: E501
#    (...)     79         thread.
#      80 """
#      81 kwargs = self._process_openapi_kwargs(kwargs)
# ---> 82 return self.call_with_http_info(**kwargs)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\Users\Admin\miniconda3\envs\lc_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'x-pinecone-api-version': '2025-04', 'access-control-allow-origin': '*', 'vary': 'origin,access-control-request-method,access-control-request-headers', 'access-control-expose-headers': '*', 'x-cloud-trace-context': 'fc4294a007e961b0a37edba5c3a0107a', 'date': 'Mon, 05 Jan 2026 06:48:49 GMT', 'server': 'Google Frontend', 'Content-Length': '233', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"RESOURCE_EXHAUSTED","message":"Request failed. You've reached the embedding token limit (5000000) for model llama-text-embed-v2 for the current month. To continue using this model, upgrade your plan."},"status":429}
